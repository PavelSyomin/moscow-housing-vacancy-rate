# %% [markdown]
# # Размеры квартир
#
# Размер = число комнат. Это нужно, чтобы более точно оценить число жителей в домах, так как число жителей в квартире по результатам переписи есть как общее (без учёта размера квартиры), так и в разбивке по числу комнат: 1, 2, 3, 4+. Данных о числе комнат по квартирам у нас нет (не нашёл), но есть данные о площади квартир по домам — можно сгруппировать площади и предположить, какому количеству комнат они соответствуют и сколько в каждом доме квартир с таким числом комнат.

# %%
from collections import Counter

import pandas as pd
from sklearn.cluster import MeanShift
import tqdm

pd.set_option("display.max_columns", None)

# %% [markdown]
# `flats` — это заранее подготовленный файл со списком квартир по домам. Получен из выгрузки объектов жилищного фонда ГИС ЖКХ ( [Реестр объектов жилищного фонда](https://dom.gosuslugi.ru/#!/houses) → «Скачать») с помощью скрипта `extract_gisgkh.py`. Процесс примерно такой: скачиваем архив, извлекаем из него только Москву (несколько csv-таблиц), запускаем скрипт.

# %%
flats = pd.read_parquet("../data/flats.parquet")
flats.columns = ["houseguid", "cn"]

# %%
flats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5318579 entries, 0 to 5318578
# Data columns (total 2 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   houseguid  object
#  1   cn         object
# dtypes: object(2)
# memory usage: 81.2+ MB

# %%
flats.head(2)
# Out:
#                               houseguid                  cn
# 0  021f35f5-fe8e-4291-b7f1-48eecca62b6e  77:01:0001026:1059
# 1  021f35f5-fe8e-4291-b7f1-48eecca62b6e  77:01:0001026:1623

# %% [markdown]
# А это тот же самый реестр из открытых данных ФРТ, что использовался в геокодировании.

# %%
houses = pd.read_csv("../data/export-reestrmkd-77-20250301.zip", sep=";", decimal=",")

# %%
houses.head(2)
# Out:
#         id                             region_id area_id city_id street_id  \
# 0  8649748  0c5b2444-70a0-4932-980c-b4dc0d3f02b5     NaN     NaN       NaN
# 1  9370109  0c5b2444-70a0-4932-980c-b4dc0d3f02b5     NaN     NaN       NaN
#
#   shortname_region formalname_region shortname_area formalname_area  \
# 0                г            Москва            NaN             NaN
# 1                г            Москва            NaN             NaN
#
#   shortname_city formalname_city shortname_street formalname_street  \
# 0            NaN             NaN              NaN               NaN
# 1            NaN             NaN              NaN               NaN
#
#   house_number building block letter                 address  \
# 0            9      NaN     1    NaN   г. Москва, д. 9, к. 1
# 1           14      NaN     1    NaN  г. Москва, д. 14, к. 1
#
#                               houseguid  management_organization_id  \
# 0  521474b9-1d5a-702f-3b75-33ff10263733                   7628409.0
# 1  64f12da8-00f6-ab7c-a849-2e1c3cccd26b                         NaN
#
#    built_year  exploitation_start_year project_type           house_type  \
# 0      1973.0                   1973.0  П-49-04/70Д  Многоквартирный дом
# 1         NaN                      NaN          NaN         Не заполнено
#
#   is_alarm   method_of_forming_overhaul_fund  floor_count_max  \
# 0      Нет  На счете регионального оператора              9.0
# 1      Нет                      Не заполнено              NaN
#
#    floor_count_min  entrance_count  elevators_count energy_efficiency  \
# 0              9.0             4.0              4.0       Не присвоен
# 1              NaN             NaN              NaN      Не заполнено
#
#    quarters_count  living_quarters_count  unliving_quarters_count  area_total  \
# 0             144                  144.0                      0.0      7219.0
# 1               0                    NaN                      NaN         NaN
#
#    area_residential  area_non_residential  area_common_property  area_land  \
# 0            4940.0                   0.0                2279.0        0.0
# 1               NaN                   NaN                   NaN        NaN
#
#    parking_square  playground  sportsground other_beautification  \
# 0             0.0         500           500                  NaN
# 1             NaN         498           498                  NaN
#
#    foundation_type      floor_type wall_material  basement_area  \
# 0  Бетонные столбы  Железобетонные     Панельные         1159.0
# 1     Не заполнено    Не заполнено  Не заполнено            NaN
#
#              chute_type  chute_count electrical_type  \
# 0  На лестничной клетке          4.0     Центральное
# 1          Не заполнено          NaN    Не заполнено
#
#    electrical_entries_count  heating_type  \
# 0                       1.0   Центральное
# 1                       NaN  Не заполнено
#
#                                   hot_water_type cold_water_type  \
# 0  Закрытая с приготовлением горячей воды на ЦТП     Центральное
# 1                                   Не заполнено    Не заполнено
#
#   sewerage_type  sewerage_cesspools_volume      gas_type     ventilation_type  \
# 0   Центральное                        0.0   Центральное  Вытяжная вентиляция
# 1  Не заполнено                        NaN  Не заполнено         Не заполнено
#
#   firefighting_type         drainage_type
# 0       Отсутствует  Внутренние водостоки
# 1      Не заполнено          Не заполнено

# %% [markdown]
# Общее поле `houseguid` позволяет объединять эти данные.

# %% [markdown]
# # Совпадает ли число квартир?
#
# Так как данные из разных источников, то на всякий случай проверим, насколько хорошо они согласуются друг с другом. У нас есть `living_quarters_count` из ФРТ, а число квартир по домам из выгрузки ГИС ЖКХ мы можем посчитать самостоятельно.

# %%
flats_by_house = flats.groupby("houseguid").nunique().reset_index()

# %%
flats_by_house["cn"].value_counts().sort_index()
# Out:
# cn
# 1       37753
# 2         178
# 3         241
# 4         116
# 5         321
#         ...
# 2995        1
# 3037        1
# 3137        1
# 3191        1
# 3844        1
# Name: count, Length: 1092, dtype: int64

# %% [markdown]
# 1 кадастровый номер на дом — это, вероятно, индивидуальные дома. Мы их не анализируем, но на всякий случай используем при объединении данных — вдруг это многоквартирные дома, где учтена только одна квартира.

# %%
houses_joined = flats_by_house.merge(houses, how="right")
houses_joined.head(2)
# Out:
#                               houseguid  cn       id  \
# 0  521474b9-1d5a-702f-3b75-33ff10263733 NaN  8649748
# 1  64f12da8-00f6-ab7c-a849-2e1c3cccd26b NaN  9370109
#
#                               region_id area_id city_id street_id  \
# 0  0c5b2444-70a0-4932-980c-b4dc0d3f02b5     NaN     NaN       NaN
# 1  0c5b2444-70a0-4932-980c-b4dc0d3f02b5     NaN     NaN       NaN
#
#   shortname_region formalname_region shortname_area formalname_area  \
# 0                г            Москва            NaN             NaN
# 1                г            Москва            NaN             NaN
#
#   shortname_city formalname_city shortname_street formalname_street  \
# 0            NaN             NaN              NaN               NaN
# 1            NaN             NaN              NaN               NaN
#
#   house_number building block letter                 address  \
# 0            9      NaN     1    NaN   г. Москва, д. 9, к. 1
# 1           14      NaN     1    NaN  г. Москва, д. 14, к. 1
#
#    management_organization_id  built_year  exploitation_start_year  \
# 0                   7628409.0      1973.0                   1973.0
# 1                         NaN         NaN                      NaN
#
#   project_type           house_type is_alarm  \
# 0  П-49-04/70Д  Многоквартирный дом      Нет
# 1          NaN         Не заполнено      Нет
#
#     method_of_forming_overhaul_fund  floor_count_max  floor_count_min  \
# 0  На счете регионального оператора              9.0              9.0
# 1                      Не заполнено              NaN              NaN
#
#    entrance_count  elevators_count energy_efficiency  quarters_count  \
# 0             4.0              4.0       Не присвоен             144
# 1             NaN              NaN      Не заполнено               0
#
#    living_quarters_count  unliving_quarters_count  area_total  \
# 0                  144.0                      0.0      7219.0
# 1                    NaN                      NaN         NaN
#
#    area_residential  area_non_residential  area_common_property  area_land  \
# 0            4940.0                   0.0                2279.0        0.0
# 1               NaN                   NaN                   NaN        NaN
#
#    parking_square  playground  sportsground other_beautification  \
# 0             0.0         500           500                  NaN
# 1             NaN         498           498                  NaN
#
#    foundation_type      floor_type wall_material  basement_area  \
# 0  Бетонные столбы  Железобетонные     Панельные         1159.0
# 1     Не заполнено    Не заполнено  Не заполнено            NaN
#
#              chute_type  chute_count electrical_type  \
# 0  На лестничной клетке          4.0     Центральное
# 1          Не заполнено          NaN    Не заполнено
#
#    electrical_entries_count  heating_type  \
# 0                       1.0   Центральное
# 1                       NaN  Не заполнено
#
#                                   hot_water_type cold_water_type  \
# 0  Закрытая с приготовлением горячей воды на ЦТП     Центральное
# 1                                   Не заполнено    Не заполнено
#
#   sewerage_type  sewerage_cesspools_volume      gas_type     ventilation_type  \
# 0   Центральное                        0.0   Центральное  Вытяжная вентиляция
# 1  Не заполнено                        NaN  Не заполнено         Не заполнено
#
#   firefighting_type         drainage_type
# 0       Отсутствует  Внутренние водостоки
# 1      Не заполнено          Не заполнено

# %%
houses_joined["cn"].isna().sum() / len(houses_joined)
# Out:
# np.float64(0.07567069129470075)

# %% [markdown]
# Около 7% домов не нашлись — странно, но ладно.

# %%
houses_joined.plot.scatter(x="living_quarters_count", y="cn")
# Out:
# <Axes: xlabel='living_quarters_count', ylabel='cn'>

# %%
houses_joined[["quarters_count", "living_quarters_count", "cn"]].corr()
# Out:
#                        quarters_count  living_quarters_count        cn
# quarters_count               1.000000               0.778776  0.800458
# living_quarters_count        0.778776               1.000000  0.753399
# cn                           0.800458               0.753399  1.000000

# %%
houses_joined[["quarters_count", "living_quarters_count", "cn"]].corr(method="spearman")
# Out:
#                        quarters_count  living_quarters_count        cn
# quarters_count               1.000000               0.981132  0.926839
# living_quarters_count        0.981132               1.000000  0.938051
# cn                           0.926839               0.938051  1.000000

# %% [markdown]
# Коэффициент ранговой корреляции выше 0.9 — ОК. По Пирсону куда меньше, но, видимо, из-за выбросов.

# %%
houses_joined.assign(diff=lambda x: x["living_quarters_count"] - x["cn"])["diff"].describe()
# Out:
# count    31011.000000
# mean        -6.908355
# std         93.705058
# min      -1619.000000
# 25%         -7.000000
# 50%         -3.000000
# 75%         -1.000000
# max       9297.000000
# Name: diff, dtype: float64

# %% [markdown]
# Не считая выбросов, кадастровых номеров обычно чуть больше, чем жилых помещений — странно, но ладно, пока не копаем глубже.

# %%
houses_joined[["houseguid", "address", "living_quarters_count", "cn"]].sample(10)
# Out:
#                                   houseguid  \
# 33886  9e0eef9c-d7c6-46b9-b855-48ac9f52ad4e
# 23313  d00e0011-1d3c-47af-933f-2f21771a2417
# 7346   481d19c5-b379-4181-b0ea-87609dfcf11f
# 10086  04431195-064c-4e97-a6af-e06e6dcfcf41
# 23462  d64d11d7-8306-4f25-be60-de5c168ab417
# 13568  85dd3455-94a3-48bd-a2ae-5ca6294ebc62
# 19139  31b74166-57d2-47c9-969c-4eee33dab2cf
# 288    ad2e3be5-2230-4eae-b489-ca571b375d1f
# 14106  a007205f-dd31-47d7-81b5-d8458e6508e8
# 872    3a121c33-6823-45dc-bd67-0840fb87e4f9
#
#                                                  address  \
# 33886                 г. Москва, ш. Энтузиастов, д. 66/1
# 23313              г. Москва, ул. Планерная, д. 16, к. 4
# 7346          г. Москва, проезд. Гурьевский, д. 19, к. 2
# 10086              г. Москва, пр-кт. Зеленый, д. 4, к. 2
# 23462                   г. Москва, пер. Плотников, д. 10
# 13568         г. Москва, ул. Красный Казанец, д. 3, к. 2
# 19139  г. Москва, проезд. Нижнелихоборский 3-й, д. 13...
# 288           г. Москва, ул. Авиаконструктора Миля, д. 7
# 14106             г. Москва, ул. Кусковская, д. 35, к. 1
# 872        г. Москва, ул. Академика Пилюгина, д. 8, к. 1
#
#        living_quarters_count     cn
# 33886                   60.0   73.0
# 23313                  100.0  101.0
# 7346                   271.0  275.0
# 10086                   95.0   97.0
# 23462                   30.0   37.0
# 13568                  144.0  145.0
# 19139                   72.0   73.0
# 288                    156.0  162.0
# 14106                   80.0   82.0
# 872                    515.0  519.0

# %% [markdown]
# В целом выглядит не идеально, но приемлемо, особенно если учесть, что других данных у нас в общем-то и нет.

# %% [markdown]
# # Кластеризуем площади квартир по домам
#
# В данных ГИС ЖКХ нет площади квартир, зато есть кадастровые номера. Площадь по кадастровым номерам есть в данных [государственной кадастровой оценки по Москве за 2023 год](https://rosreestr.gov.ru/wps/portal/p/cc_ib_portal_services/cc_ib_ais_fdgko/!ut/p/z1/lZLdTsIwFMefhQfQtkIot2PRBTA6VIT2xpRx0jTpV7rOZG9vJyZGCGw2vTk5v_9HkyKOdohb8amkiMpZodPM-PSjWE_uST4hq2Izn-JsUS7n74scY0zR9gRYE5qAbEXGpMD4mSD-P_0Z0OnxhZPhpOcnEX8b5Hc9QFexL4SlkvRiyRlGr51H5WwMTmsIiGlVxxfwLsS6WxlR18fxMS0elI4QlJW3lYggXWjfWg-I3ZBrbACh4yDSB1fBoQkwBLaN2XeNz5lSyG83IeHpB7rqJLzX7XFELIYG-mOHvVumv5i7QyIpRd5sdliVxszGvzcbjb4AEH-4GQ!!/p0/IZ7_GQ4E1C41KGUB60AIPJBVIC0080=CZ6_GQ4E1C41KGUB60AIPJBVIC0007=MEcontroller!null==/?restoreSessionState=true&action=viewProcedure&id=22543&showRep=true): «Отчет № 1/2023  составлен 22.08.2023» → «Скачать».
#
# `flats_area.csv` — файл с площадью жилых помещений по кадастровым номерам, полученный с помощью скрипта `extract_ce.py`. Скрипт принимает на вход несколько Excel-таблиц из `1 Исходные данные.zip::1 Исходные данные/3. Сведения об ОН в перечне/2. Помещения/Помещения Жилые*`.

# %%
flats_area = pd.read_parquet("../data/flats_area.parquet")
flats_area.columns = ["cn", "area"]
flats_area.head(2)
# Out:
#                       cn  area
# index
# 0      50:10:0050109:251  36.8
# 1      50:10:0050109:252  69.2

# %% [markdown]
# Нам нужен `houseguid`, так как он позволяет объединить результат с данными ФРТ.

# %%
flats_joined = flats.loc[
    flats["houseguid"].isin(flats_by_house.loc[flats_by_house["cn"] > 1]["houseguid"].unique())
].merge(flats_area, how="left")
flats_joined.head(2)
# Out:
#                               houseguid                  cn  area
# 0  021f35f5-fe8e-4291-b7f1-48eecca62b6e  77:01:0001026:1059   NaN
# 1  021f35f5-fe8e-4291-b7f1-48eecca62b6e  77:01:0001026:1623  86.9

# %%
flats_joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5278038 entries, 0 to 5278037
# Data columns (total 3 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   houseguid  object
#  1   cn         object
#  2   area       float64
# dtypes: float64(1), object(2)
# memory usage: 120.8+ MB

# %%
flats_joined["area"].isna().sum() / len(flats_joined)
# Out:
# 0.10550726258534313

# %% [markdown]
# 10% пропусков — терпимо: у нас и в других местах примерно так же получалось.
#
# Дальше будет медленно (у меня где-то два часа считалось), так как `MeanShift` — сравнительно небыстрый алгоритм. Зато хорошо (как мне кажется) группирует данные с мультимодальным распределением, которым характеризуются площади квартир по домам и не требует заранее знать число кластеров.

# %%
msc = MeanShift(n_jobs=3)

result = []
for label, group in tqdm.tqdm(flats_joined.groupby("houseguid")):
    na_cnt = group["area"].isna().sum()
    if na_cnt == len(group):
        continue

    try:
        msc.fit(group[["area"]].dropna())
        centers = msc.cluster_centers_
        counts = Counter(msc.labels_)
        
        for cluster_label, n_flats in counts.items():
            result.append((label, cluster_label, n_flats, centers[cluster_label][0]))
    except:
        continue
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 35234/35234 [2:38:32<00:00,  3.70it/s]

# %%
clusters = pd.DataFrame(result, columns=["houseguid", "cluster_label", "n_flats", "mean_area"])
clusters.head(30)
# Out:
#                                houseguid  cluster_label  n_flats   mean_area
# 0   00065add-ac65-4dea-9759-285169ea505f              1       18  165.422222
# 1   00065add-ac65-4dea-9759-285169ea505f              0       52  117.134615
# 2   00065add-ac65-4dea-9759-285169ea505f              2        3  229.466667
# 3   00065add-ac65-4dea-9759-285169ea505f              4        2  194.400000
# 4   00065add-ac65-4dea-9759-285169ea505f              5        2   79.050000
# 5   00065add-ac65-4dea-9759-285169ea505f              3        2  273.250000
# 6   00095edb-6cf9-41b4-985c-bf942cf9717e              0       40   64.000000
# 7   00095edb-6cf9-41b4-985c-bf942cf9717e              1       30   29.806667
# 8   0009f2bb-b015-43c7-a166-51a33911c520              1       27   46.185185
# 9   0009f2bb-b015-43c7-a166-51a33911c520              0       55   36.823636
# 10  0009f2bb-b015-43c7-a166-51a33911c520              2       13   64.253846
# 11  000a0da4-73ca-4ce6-86a8-5de2ec4dcddd              1       35   48.734286
# 12  000a0da4-73ca-4ce6-86a8-5de2ec4dcddd              0       47   32.410638
# 13  000a0da4-73ca-4ce6-86a8-5de2ec4dcddd              2       12   66.983333
# 14  000a0da4-73ca-4ce6-86a8-5de2ec4dcddd              3        1   84.700000
# 15  000bfbb7-0d1b-4372-978c-30d03fbb4542              1       28   31.123077
# 16  000bfbb7-0d1b-4372-978c-30d03fbb4542              0       35   36.740000
# 17  000bfbb7-0d1b-4372-978c-30d03fbb4542              2        8   43.675000
# 18  000e49e8-1c7e-42c6-90cb-9349c512a349              2       18   34.172222
# 19  000e49e8-1c7e-42c6-90cb-9349c512a349              1       19   45.142105
# 20  000e49e8-1c7e-42c6-90cb-9349c512a349              0       33   60.842424
# 21  00132426-0b90-4f06-b4ef-702459c54ef4              0       72   42.497917
# 22  00132426-0b90-4f06-b4ef-702459c54ef4              1       12   64.508333
# 23  0013c32a-c5e6-441c-be39-248e7bfc3122              0      184  104.852688
# 24  0013c32a-c5e6-441c-be39-248e7bfc3122              1      137   73.922330
# 25  0013c32a-c5e6-441c-be39-248e7bfc3122              2       55  131.695238
# 26  0014723a-3bfc-4280-bd61-6fd551bde36c              1      108   74.887037
# 27  0014723a-3bfc-4280-bd61-6fd551bde36c              2      108   37.622222
# 28  0014723a-3bfc-4280-bd61-6fd551bde36c              0      159   55.331447
# 29  0015b64b-3e46-45a3-8dc2-e3bae13588dc              2       10   31.670000

# %%
clusters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128545 entries, 0 to 128544
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   houseguid      128545 non-null  object
#  1   cluster_label  128545 non-null  int64
#  2   n_flats        128545 non-null  int64
#  3   mean_area      128545 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 3.9+ MB

# %% [markdown]
# В основном у нас 3–4 кластера, что ожидаемо, так как обычно в домах будет несколько, но не слишком много вариантов квартир с разным числом комнат.

# %%
clusters.groupby("houseguid").size().value_counts()
# Out:
# 3     15098
# 4      9983
# 5      4615
# 2      2381
# 6      1695
# 7       496
# 1       204
# 8       154
# 9        32
# 10        8
# 12        3
# Name: count, dtype: int64

# %%
clusters["n_flats"].value_counts().sort_index()
# Out:
# n_flats
# 1       17342
# 2        5339
# 3        3520
# 4        3255
# 5        2886
#         ...
# 1083        1
# 1121        1
# 1162        1
# 1178        1
# 1386        1
# Name: count, Length: 531, dtype: int64

# %%
clusters.loc[clusters["n_flats"] >= 10].groupby("houseguid").size().value_counts()
# Out:
# 3    17063
# 2     8027
# 4     3958
# 1     2324
# 5      280
# 6       13
# Name: count, dtype: int64

# %%
clusters["share"] = clusters["n_flats"] / clusters.groupby("houseguid")["n_flats"].transform("sum")

# %%
clusters.loc[clusters["share"] >= .1].groupby("houseguid").size().value_counts()
# Out:
# 3    21322
# 2     8362
# 4     3944
# 1      530
# 5      319
# 6      179
# 7       13
# Name: count, dtype: int64

# %% [markdown]
# Так как кластеризация медленная, то сохраним промежуточный результат.

# %%
clusters.to_parquet("../data/houses_with_flat_size_counts.parquet", index=False)

# %% [markdown]
# # Переводим результаты кластеризации в число комнат в квартирах
#
# Алгоритм примерно такой:
# - убираем небольшие кластеры (1 квартира или меньше 10% квартир в доме);
# - упорядочиваем квартиры по возрастанию площади, ранжируем. Ранг — это условное число комнат, то есть предполагаем, что квартира с наименьшим числом комнат в доме — однокомнатная;
# - убираем дома с более чем 4 вариантами квартир, так как у нас все равно есть данные переписи только для 1–4 комнат и так как вариантов с 5+ кластерами после очистки результатов немного;
# - корректируем число квартир так, чтобы сумма совпадала с числом комнат по данным ФРТ. Количество квартир с разным числом комнат в результате исказится и может стать даже дробным, но на это не обращаем внимание, так как в конечном итоге нам важна пропорция;
# - корректируем ранг так, чтобы он более адекватно отражал число комнат, потому что однокомнатная площадью 100+ квадратных метров — это неправдоподобно (равно как и некоторые другие варианты, которые есть в `fix_n_rooms`);
# - сохраняем результат для дальнейшего использования.

# %%
clusters = pd.read_parquet("../data/houses_with_flat_size_counts.parquet")

# %%
clusters = clusters.sort_values(["houseguid", "mean_area"])

# %%
clusters["total_flats"] = clusters.groupby("houseguid")["n_flats"].transform("sum")
clusters["flats_share"] = clusters["n_flats"] / clusters["total_flats"]
clusters = clusters.loc[(clusters["flats_share"] >= .1) & (clusters["n_flats"] > 1)].copy()

# %%
clusters["n_rooms"] = clusters.groupby("houseguid")["mean_area"].rank(method="first")
clusters["n_flat_types"] = clusters.groupby("houseguid").transform("size")

# %%
clusters.head(20)
# Out:
#                                houseguid  cluster_label  n_flats   mean_area  \
# 1   00065add-ac65-4dea-9759-285169ea505f              0       52  117.134615
# 0   00065add-ac65-4dea-9759-285169ea505f              1       18  165.422222
# 7   00095edb-6cf9-41b4-985c-bf942cf9717e              1       30   29.806667
# 6   00095edb-6cf9-41b4-985c-bf942cf9717e              0       40   64.000000
# 9   0009f2bb-b015-43c7-a166-51a33911c520              0       55   36.823636
# 8   0009f2bb-b015-43c7-a166-51a33911c520              1       27   46.185185
# 10  0009f2bb-b015-43c7-a166-51a33911c520              2       13   64.253846
# 12  000a0da4-73ca-4ce6-86a8-5de2ec4dcddd              0       47   32.410638
# 11  000a0da4-73ca-4ce6-86a8-5de2ec4dcddd              1       35   48.734286
# 13  000a0da4-73ca-4ce6-86a8-5de2ec4dcddd              2       12   66.983333
# 15  000bfbb7-0d1b-4372-978c-30d03fbb4542              1       28   31.123077
# 16  000bfbb7-0d1b-4372-978c-30d03fbb4542              0       35   36.740000
# 17  000bfbb7-0d1b-4372-978c-30d03fbb4542              2        8   43.675000
# 18  000e49e8-1c7e-42c6-90cb-9349c512a349              2       18   34.172222
# 19  000e49e8-1c7e-42c6-90cb-9349c512a349              1       19   45.142105
# 20  000e49e8-1c7e-42c6-90cb-9349c512a349              0       33   60.842424
# 21  00132426-0b90-4f06-b4ef-702459c54ef4              0       72   42.497917
# 22  00132426-0b90-4f06-b4ef-702459c54ef4              1       12   64.508333
# 24  0013c32a-c5e6-441c-be39-248e7bfc3122              1      137   73.922330
# 23  0013c32a-c5e6-441c-be39-248e7bfc3122              0      184  104.852688
#
#        share  total_flats  flats_share  n_rooms  n_flat_types
# 1   0.658228           79     0.658228      1.0             2
# 0   0.227848           79     0.227848      2.0             2
# 7   0.428571           70     0.428571      1.0             2
# 6   0.571429           70     0.571429      2.0             2
# 9   0.578947           95     0.578947      1.0             3
# 8   0.284211           95     0.284211      2.0             3
# 10  0.136842           95     0.136842      3.0             3
# 12  0.494737           95     0.494737      1.0             3
# 11  0.368421           95     0.368421      2.0             3
# 13  0.126316           95     0.126316      3.0             3
# 15  0.394366           71     0.394366      1.0             3
# 16  0.492958           71     0.492958      2.0             3
# 17  0.112676           71     0.112676      3.0             3
# 18  0.257143           70     0.257143      1.0             3
# 19  0.271429           70     0.271429      2.0             3
# 20  0.471429           70     0.471429      3.0             3
# 21  0.857143           84     0.857143      1.0             2
# 22  0.142857           84     0.142857      2.0             2
# 24  0.364362          376     0.364362      1.0             3
# 23  0.489362          376     0.489362      2.0             3

# %%
clusters.groupby("houseguid").size().value_counts()
# Out:
# 3    21157
# 2     8327
# 4     3498
# 1      560
# 5       69
# 6        1
# Name: count, dtype: int64

# %%
clusters = clusters.loc[clusters["n_flat_types"] <= 4].copy()

# %%
clusters.groupby("houseguid").size().value_counts()
# Out:
# 3    21157
# 2     8327
# 4     3498
# 1      560
# Name: count, dtype: int64

# %%
clusters.groupby("n_rooms")["mean_area"].describe()
# Out:
#            count       mean        std        min        25%        50%  \
# n_rooms
# 1.0      33542.0  42.393594  23.110664   6.750000  31.840000  36.893304
# 2.0      32982.0  59.415648  28.744066  13.850000  44.511750  52.365671
# 3.0      24655.0  70.520546  27.814686  20.900000  56.360000  64.360714
# 4.0       3498.0  84.321079  28.924725  34.865217  71.757973  76.262057
#
#                75%         max
# n_rooms
# 1.0      44.960479  684.280000
# 2.0      64.128373  699.778571
# 3.0      75.837928  916.000000
# 4.0      93.931960  464.966667

# %%
clusters.sort_values("mean_area")
# Out:
#                                    houseguid  cluster_label  n_flats  \
# 70657   8b83e5ce-58da-44a8-b409-322d4433bbf3              2        2
# 119836  ee04ef42-d798-4cec-977d-008f99afba05              2        5
# 117493  e946b048-be54-4f74-ba8f-2937cd04ceee              2        7
# 16051   1f5d89b2-19f5-4833-8fd7-f3df68c94c26              3        2
# 105423  d179b4a7-475f-4499-8a2f-192ca1ed15ca              2        9
# ...                                      ...            ...      ...
# 79144   9c4cbfd1-8da6-45ad-8887-c234f4c162c7              1        2
# 111413  dd170037-0b54-44d3-b7a9-9790720d5497              0        6
# 45885   5ab750f5-b5f7-4b37-bb8e-43101b025f79              1       14
# 45920   5ac95a7b-e227-4de7-b2ef-9f7fe187836f              2        2
# 59719   75ee5213-0e7f-4744-8da8-4039be84dc87              1        2
#
#          mean_area     share  total_flats  flats_share  n_rooms  n_flat_types
# 70657     6.750000  0.105263           19     0.105263      1.0             4
# 119836    7.766667  0.208333           24     0.208333      1.0             4
# 117493    8.212500  0.218750           32     0.218750      1.0             3
# 16051     8.900000  0.181818           11     0.181818      1.0             4
# 105423    8.911111  0.225000           40     0.225000      1.0             3
# ...            ...       ...          ...          ...      ...           ...
# 79144   682.650000  0.166667           12     0.166667      2.0             2
# 111413  684.280000  0.750000            8     0.750000      1.0             1
# 45885   699.778571  0.259259           54     0.259259      2.0             2
# 45920   730.800000  0.133333           15     0.133333      3.0             3
# 59719   916.000000  0.181818           11     0.181818      3.0             3
#
# [94677 rows x 9 columns]

# %%
clusters = clusters.merge(houses[["houseguid", "living_quarters_count"]].drop_duplicates("houseguid"), how="left")

# %%
clusters["n_flats"] = clusters["n_flats"] * clusters["living_quarters_count"].combine_first(clusters["total_flats"]) / clusters["total_flats"]
clusters["n_rooms"] = clusters["n_rooms"].astype(int)
clusters.head(2)
# Out:
#                               houseguid  cluster_label    n_flats   mean_area  \
# 0  00065add-ac65-4dea-9759-285169ea505f              0  53.316456  117.134615
# 1  00065add-ac65-4dea-9759-285169ea505f              1  18.455696  165.422222
#
#       share  total_flats  flats_share  n_rooms  n_flat_types  \
# 0  0.658228           79     0.658228        1             2
# 1  0.227848           79     0.227848        2             2
#
#    living_quarters_count
# 0                   81.0
# 1                   81.0

# %%
clusters.groupby("houseguid").size().value_counts()
# Out:
# 3    21157
# 2     8327
# 4     3498
# 1      560
# Name: count, dtype: int64

# %%
def fix_n_rooms(group: pd.DataFrame) -> pd.DataFrame:
    # «Московский статистический ежегодник — 2023», с. 64, «Средний размер одной квартиры» за 2022 г.
    # Для 4+ комнат там слишком большое и неудобное для алгоритма значение, поэтому поставил 90
    mean_flat_areas = dict(zip(range(1, 5), (38, 52, 73, 90)))

    n_flat_types = group["n_flat_types"].max()
    mean_area_smallest = group.loc[group["n_rooms"] == 1.0, "mean_area"].iat[0]
    
    if n_flat_types == 3:
        if mean_area_smallest > mean_flat_areas[1]:
            group["n_rooms"] += 1
    elif n_flat_types == 2:
        area_diff = group["mean_area"].max() - group["mean_area"].min()
        if mean_area_smallest > mean_flat_areas[2]:
            group["n_rooms"] += 2
        elif mean_area_smallest > mean_flat_areas[1]:
            if area_diff < mean_area_smallest / 2:
                group["n_rooms"] += 1
            else:
                group["n_rooms"] = [2, 4]
        else:
            if area_diff < mean_area_smallest / 2:
                group["n_rooms"] += 1
            else:
                group["n_rooms"] = [1, 3]
    elif n_flat_types == 1:
        scores = [
            (n_rooms, abs(mean_flat_area - mean_area_smallest))
            for n_rooms, mean_flat_area in mean_flat_areas.items()
        ]
        group["n_rooms"] = sorted(scores, key=lambda x: x[1])[0][0]

    return group

# %%
clusters = clusters.groupby("houseguid").apply(fix_n_rooms).reset_index(drop=True)
clusters.head(2)
# Out:
# /tmp/ipykernel_8789/3353923124.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   clusters = clusters.groupby("houseguid").apply(fix_n_rooms).reset_index(drop=True)
#                               houseguid  cluster_label    n_flats   mean_area  \
# 0  00065add-ac65-4dea-9759-285169ea505f              0  53.316456  117.134615
# 1  00065add-ac65-4dea-9759-285169ea505f              1  18.455696  165.422222
#
#       share  total_flats  flats_share  n_rooms  n_flat_types  \
# 0  0.658228           79     0.658228        3             2
# 1  0.227848           79     0.227848        4             2
#
#    living_quarters_count
# 0                   81.0
# 1                   81.0

# %%
clusters.isna().sum()
# Out:
# houseguid                    0
# cluster_label                0
# n_flats                      0
# mean_area                    0
# share                        0
# total_flats                  0
# flats_share                  0
# n_rooms                      0
# n_flat_types                 0
# living_quarters_count    10107
# dtype: int64

# %%
clusters[["houseguid", "n_rooms", "n_flats"]].to_parquet("../data/flats_by_n_rooms.parquet", index=False)
