# %% [markdown]
# # Оценка вакантности по домам (метод №1)
#
# Самый главный шаг с попыткой ответа на основной вопрос исследования. В трёх предыдущих готовились вспомогательные данные, а тут идут основные расчёты.
#
# ## Идея
#
# Берём дом. Мы знаем общее число жителей и число квартир. Мы также знаем, сколько человек в среднем живёт в одной *непустой* квартире. Значит, мы можем посчитать число непустых квартир: делим общее число жителей на среднее число жителей в непустой квартире. Раз так, то мы знаем и число пустых квартир: общее минус число непустых.
#
# ## Нюансы
#
# 1. Общее число жителей — это на самом деле число зарегистрированных. Оно не обязательно точное. Впрочем, оно хорошо коррелирует с общедомовым потреблением электроэнергии, так что считаем, что всё ОК.
# 2. Среднее число проживающих в непустой квартире у нас есть только по муниципалитетам — предполагаем, что оно неизменно во всех домах муниципалитета. Это неправда, но как есть.
# 3. У нас куча пропусков в данных и прочих проблем — тут тоже как есть.

# %%
import numpy as np
import pandas as pd

pd.set_option("display.max_columns", None)

# %% [markdown]
# - `flat_sizes` — число квартир с разным количеством комнат по домам из тетрадки №3
# - `geo` — координаты домов из тетрадки №1
# - `houses` — открытые данные ФРТ по домам (те же, что в тетрадке №1)
# - `ppf_by_mo` — среднее число жителей непустых квартир по данным переписи (из тетрадки №2)
# - `repair_data` — открытые данные ФРТ по капремонту (те же, что в тетрадке №2)

# %%
flat_sizes = pd.read_parquet("../data/flats_by_n_rooms.parquet")
geo = pd.read_parquet("../data/houses_coords.parquet")
houses = pd.read_csv("../data/export-reestrmkd-77-20250301.zip", sep=";", decimal=",")
ppf_by_mo = pd.read_parquet("../data/ppf_by_mo.parquet")
repair_data = pd.read_csv("../data/export-kr1_1-77-20250301.zip", sep=";", decimal=",")

# %% [markdown]
# Дальше просто посмотрим на данные.

# %%
flat_sizes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94677 entries, 0 to 94676
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   houseguid  94677 non-null  object
#  1   n_rooms    94677 non-null  int64
#  2   n_flats    94677 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
flat_sizes.head()
# Out:
#                               houseguid  n_rooms    n_flats
# 0  00065add-ac65-4dea-9759-285169ea505f        3  53.316456
# 1  00065add-ac65-4dea-9759-285169ea505f        4  18.455696
# 2  00095edb-6cf9-41b4-985c-bf942cf9717e        1  25.714286
# 3  00095edb-6cf9-41b4-985c-bf942cf9717e        3  34.285714
# 4  0009f2bb-b015-43c7-a166-51a33911c520        1  55.000000

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34703 entries, 0 to 34702
# Data columns (total 60 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               34703 non-null  int64
#  1   region_id                        34703 non-null  object
#  2   area_id                          1319 non-null   object
#  3   city_id                          2644 non-null   object
#  4   street_id                        33568 non-null  object
#  5   shortname_region                 34703 non-null  object
#  6   formalname_region                34703 non-null  object
#  7   shortname_area                   1319 non-null   object
#  8   formalname_area                  1319 non-null   object
#  9   shortname_city                   2644 non-null   object
#  10  formalname_city                  2644 non-null   object
#  11  shortname_street                 33568 non-null  object
#  12  formalname_street                33568 non-null  object
#  13  house_number                     34233 non-null  object
#  14  building                         1748 non-null   object
#  15  block                            16168 non-null  object
#  16  letter                           16 non-null     object
#  17  address                          34703 non-null  object
#  18  houseguid                        34703 non-null  object
#  19  management_organization_id       32450 non-null  float64
#  20  built_year                       33064 non-null  float64
#  21  exploitation_start_year          34191 non-null  float64
#  22  project_type                     34136 non-null  object
#  23  house_type                       34703 non-null  object
#  24  is_alarm                         34703 non-null  object
#  25  method_of_forming_overhaul_fund  34703 non-null  object
#  26  floor_count_max                  34257 non-null  float64
#  27  floor_count_min                  32989 non-null  float64
#  28  entrance_count                   34221 non-null  float64
#  29  elevators_count                  34166 non-null  float64
#  30  energy_efficiency                34703 non-null  object
#  31  quarters_count                   34703 non-null  int64
#  32  living_quarters_count            33010 non-null  float64
#  33  unliving_quarters_count          32917 non-null  float64
#  34  area_total                       34323 non-null  float64
#  35  area_residential                 34212 non-null  float64
#  36  area_non_residential             34105 non-null  float64
#  37  area_common_property             32836 non-null  float64
#  38  area_land                        33544 non-null  float64
#  39  parking_square                   32166 non-null  float64
#  40  playground                       34703 non-null  int64
#  41  sportsground                     34703 non-null  int64
#  42  other_beautification             22221 non-null  object
#  43  foundation_type                  34703 non-null  object
#  44  floor_type                       34703 non-null  object
#  45  wall_material                    34703 non-null  object
#  46  basement_area                    33823 non-null  float64
#  47  chute_type                       34703 non-null  object
#  48  chute_count                      33767 non-null  float64
#  49  electrical_type                  34703 non-null  object
#  50  electrical_entries_count         33390 non-null  float64
#  51  heating_type                     34703 non-null  object
#  52  hot_water_type                   34703 non-null  object
#  53  cold_water_type                  34703 non-null  object
#  54  sewerage_type                    34703 non-null  object
#  55  sewerage_cesspools_volume        31096 non-null  float64
#  56  gas_type                         34703 non-null  object
#  57  ventilation_type                 34703 non-null  object
#  58  firefighting_type                34703 non-null  object
#  59  drainage_type                    34703 non-null  object
# dtypes: float64(19), int64(4), object(37)
# memory usage: 15.9+ MB

# %%
houses.sample(2)
# Out:
#             id                             region_id area_id city_id  \
# 7928   7645232  0c5b2444-70a0-4932-980c-b4dc0d3f02b5     NaN     NaN
# 30980  7689876  0c5b2444-70a0-4932-980c-b4dc0d3f02b5     NaN     NaN
#
#                                   street_id shortname_region  \
# 7928   2202650e-00a5-4e05-b7dc-d2138a2d2468                г
# 30980  eaf6d52e-31d3-409e-a180-d82f98e8b055                г
#
#       formalname_region shortname_area formalname_area shortname_city  \
# 7928             Москва            NaN             NaN            NaN
# 30980            Москва            NaN             NaN            NaN
#
#       formalname_city shortname_street formalname_street house_number  \
# 7928              NaN                ш       Дмитровское           45
# 30980             NaN               ул      Филевская М.            8
#
#       building block letter                                  address  \
# 7928       NaN     1    NaN   г. Москва, ш. Дмитровское, д. 45, к. 1
# 30980      NaN     1    NaN  г. Москва, ул. Филевская М., д. 8, к. 1
#
#                                   houseguid  management_organization_id  \
# 7928   e21509fb-9817-4745-980a-921421c690e5                   7555117.0
# 30980  e7533c9e-145d-400f-9bdc-0325306033c1                   7680834.0
#
#        built_year  exploitation_start_year           project_type  \
# 7928       1970.0                   1970.0                  I-515
# 30980      1962.0                   1962.0  индивидуальный проект
#
#                 house_type is_alarm  \
# 7928   Многоквартирный дом      Нет
# 30980  Многоквартирный дом      Нет
#
#                       method_of_forming_overhaul_fund  floor_count_max  \
# 7928                 На счете регионального оператора              9.0
# 30980  На специальном счете у регионального оператора              5.0
#
#        floor_count_min  entrance_count  elevators_count energy_efficiency  \
# 7928               9.0             4.0              4.0                 D
# 30980              1.0             4.0              0.0                 A
#
#        quarters_count  living_quarters_count  unliving_quarters_count  \
# 7928              144                  144.0                      0.0
# 30980              83                   79.0                      4.0
#
#        area_total  area_residential  area_non_residential  \
# 7928       7223.6            7223.6                   0.0
# 30980      5146.6            3449.1                 631.5
#
#        area_common_property  area_land  parking_square  playground  \
# 7928                 1514.2        0.0             0.0         500
# 30980                1066.0     4903.0             0.0         499
#
#        sportsground other_beautification foundation_type      floor_type  \
# 7928            500           Не имеется       Ленточный  Железобетонные
# 30980           499                    0    Не заполнено    Не заполнено
#
#       wall_material  basement_area            chute_type  chute_count  \
# 7928    Железобетон         1190.0  На лестничной клетке          4.0
# 30980  Не заполнено          673.0          Не заполнено          0.0
#
#       electrical_type  electrical_entries_count  heating_type  \
# 7928      Центральное                       1.0   Центральное
# 30980    Не заполнено                       1.0  Не заполнено
#
#                                       hot_water_type cold_water_type  \
# 7928   Закрытая с приготовлением горячей воды на ЦТП     Центральное
# 30980                                   Не заполнено    Не заполнено
#
#       sewerage_type  sewerage_cesspools_volume      gas_type  \
# 7928    Центральное                        0.0   Центральное
# 30980  Не заполнено                        3.0  Не заполнено
#
#                    ventilation_type firefighting_type         drainage_type
# 7928   Приточно-вытяжная вентиляция       Отсутствует  Внутренние водостоки
# 30980                  Не заполнено      Не заполнено          Не заполнено

# %%
geo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33545 entries, 0 to 33544
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   house_id  33545 non-null  int64
#  1   lat       31206 non-null  float64
#  2   lon       31206 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 786.3 KB

# %%
geo.head()
# Out:
#    house_id        lat        lon
# 0   8929489  55.727066  37.560168
# 1   8065593  55.727066  37.560168
# 2   7847597  55.734999  37.524101
# 3   7847598  55.736789  37.524575
# 4   7847599  55.736122  37.523309

# %%
ppf_by_mo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sheet_name  980 non-null    object
#  1   ppf         944 non-null    float64
#  2   n_rooms     980 non-null    int64
#  3   mun_obr     980 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 30.8+ KB

# %%
ppf_by_mo.head()
# Out:
#       sheet_name       ppf  n_rooms              mun_obr
# 0  Академическое  3.113928       -1  Академический район
# 1  Академическое  2.138218        1  Академический район
# 2  Академическое  2.862416        2  Академический район
# 3  Академическое  3.583501        3  Академический район
# 4  Академическое  4.734848        4  Академический район

# %%
repair_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29819 entries, 0 to 29818
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   subject_rf                       29819 non-null  object
#  1   mun_obr_oktmo                    29819 non-null  int64
#  2   mun_obr                          29819 non-null  object
#  3   mkd_code                         29819 non-null  int64
#  4   houseguid                        29819 non-null  object
#  5   address                          29819 non-null  object
#  6   commission_year                  29819 non-null  int64
#  7   architectural_monument_category  0 non-null      float64
#  8   total_sq                         29819 non-null  float64
#  9   total_rooms_amount               29819 non-null  int64
#  10  living_rooms_amount              29819 non-null  int64
#  11  total_rooms_sq                   29819 non-null  float64
#  12  living_rooms_sq                  29819 non-null  float64
#  13  total_ppl                        29819 non-null  int64
#  14  number_floors_max                29819 non-null  int64
#  15  money_collecting_way             29819 non-null  object
#  16  money_ppl_collected              29819 non-null  float64
#  17  money_ppl_collected_debts        24553 non-null  float64
#  18  overhaul_funds_spent_all         29819 non-null  float64
#  19  overhaul_funds_spent_subsidy     94 non-null     float64
#  20  overhaul_fund_spent_other        0 non-null      float64
#  21  overhaul_funds_balance           29819 non-null  float64
#  22  update_date_of_information       29819 non-null  object
#  23  money_ppl_collected_date         29611 non-null  object
#  24  owners_payment                   29725 non-null  float64
#  25  energy_efficiency                0 non-null      float64
#  26  alarm_document_date              0 non-null      float64
#  27  exclude_date_from_program        94 non-null     object
#  28  inclusion_date_to_program        29819 non-null  object
#  29  comment                          3204 non-null   float64
#  30  last_update                      29819 non-null  object
#  31  house_id                         27598 non-null  float64
# dtypes: float64(15), int64(7), object(10)
# memory usage: 7.3+ MB

# %%
repair_data.head()
# Out:
#      subject_rf  mun_obr_oktmo              mun_obr  mkd_code  \
# 0  город Москва       45397000  Академический район    108367
# 1  город Москва       45397000  Академический район    104062
# 2  город Москва       45397000  Академический район    100329
# 3  город Москва       45397000  Академический район     97512
# 4  город Москва       45397000  Академический район     97558
#
#                               houseguid                         address  \
# 0  fa844609-84ef-4f05-8414-74b25c56fce1    60-летия Октября просп. 10/1
# 1  6793bac3-20b7-4e42-b53a-73dc9be6c309      60-летия Октября просп. 12
# 2  c55b1076-d005-4c06-8a12-c30c57172e0f      60-летия Октября просп. 14
# 3  7f78f929-ef62-4ed4-9e70-c9499a617dee  60-летия Октября просп. 16 к.1
# 4  fb804b85-7549-446b-ac31-d4b07066952b  60-летия Октября просп. 16 к.2
#
#    commission_year  architectural_monument_category  total_sq  \
# 0             1964                              NaN    3448.0
# 1             1963                              NaN    3457.0
# 2             1959                              NaN    4094.0
# 3             1958                              NaN    4041.0
# 4             1959                              NaN    3041.0
#
#    total_rooms_amount  living_rooms_amount  total_rooms_sq  living_rooms_sq  \
# 0                  71                   68         3352.46          2429.13
# 1                  75                   68         3251.41          2539.72
# 2                  84                   79         3983.79          3283.73
# 3                  87                   78         3935.52          3022.51
# 4                  60                   59         2518.34          2363.60
#
#    total_ppl  number_floors_max          money_collecting_way  \
# 0        136                  9  Счет регионального оператора
# 1        129                  9  Счет регионального оператора
# 2        175                  5  Счет регионального оператора
# 3        207                  5  Счет регионального оператора
# 4        152                  5  Счет регионального оператора
#
#    money_ppl_collected  money_ppl_collected_debts  overhaul_funds_spent_all  \
# 0           7059.18318                   22.57946                1597.26244
# 1           6772.90899                   90.33989               13380.14323
# 2           7867.24191                  552.32016               24555.32438
# 3           8076.66261                  231.47770               18975.36421
# 4           5308.04020                    7.95719               16432.23201
#
#    overhaul_funds_spent_subsidy  overhaul_fund_spent_other  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
#
#    overhaul_funds_balance update_date_of_information money_ppl_collected_date  \
# 0              5461.92074                 2025-01-15               01.01.2015
# 1             -6607.23424                 2025-01-15               01.01.2015
# 2            -16688.08247                 2025-01-15               01.01.2015
# 3            -10898.70160                 2025-01-15               01.01.2015
# 4            -11124.19181                 2025-01-15               01.01.2015
#
#    owners_payment  energy_efficiency  alarm_document_date  \
# 0           29.66                NaN                  NaN
# 1           29.66                NaN                  NaN
# 2           29.66                NaN                  NaN
# 3           29.66                NaN                  NaN
# 4           29.66                NaN                  NaN
#
#   exclude_date_from_program inclusion_date_to_program  comment last_update  \
# 0                       NaN                29.12.2014      NaN  23.01.2025
# 1                       NaN                29.12.2014      NaN  23.01.2025
# 2                       NaN                29.12.2014      NaN  23.01.2025
# 3                       NaN                29.12.2014      NaN  23.01.2025
# 4                       NaN                29.12.2014      NaN  23.01.2025
#
#     house_id
# 0  8004177.0
# 1  8004180.0
# 2  8004181.0
# 3  8004183.0
# 4  8004187.0

# %% [markdown]
# # Объединение всего со всем
#
# Интересующие переменные разбросаны по куче файлов, поэтому объединяем всё и заодно убираем лишнее, считая по пути, сколько данных остаётся.
#
# Начальное число — в следующей ячейке (почти 35 тысяч).

# %%
len(houses)
# Out:
# 34703

# %% [markdown]
# Убираем дома, для которых не знаем число жилых помещений, или дома, для которых не знаем жилую площадь, или дома, где средняя площадь квартиры странная. Например, там есть дома с площадью 10 тысяч м² и с 10 тысячами квартир — видимо, что это ошибка.

# %%
houses_filtered = (
    houses
    .dropna(subset="living_quarters_count")
    .query("area_residential > 0 and living_quarters_count > 0")
    .query("area_residential / living_quarters_count > 6")
)
len(houses_filtered)
# Out:
# 32369

# %% [markdown]
# Также у нас есть дубли в `houseguid`, которые нежелательны, так как мы потом по `houseguid` присоединяем число квартир с разными количеством комнат. Откуда эти дубли взялись, непонятно, но удаляем.

# %%
houses_deduplicated = houses_filtered.drop_duplicates(subset="houseguid")
len(houses_deduplicated)
# Out:
# 32289

# %% [markdown]
# Сразу ушло около 10% данных. Теперь присоединяем координаты.

# %%
houses_geocoded = (
    houses_deduplicated[[
        "id", 
        "houseguid", 
        "exploitation_start_year", 
        "living_quarters_count",
        "area_residential",
        "address",
    ]]
    .rename(columns={"id": "house_id"})
    .merge(
        geo, 
        how="left", 
        on="house_id"
    )
    .dropna(subset=["lat", "lon"], how="any")
)
len(houses_geocoded)
# Out:
# 29190

# %% [markdown]
# Уже почти 6 тысяч домов исключено из анализа — многовато, но ещё не вечер. Теперь очень важный шаг: присоединяем датасет по капремонту, так как только в нём есть сведения о числе зарегистрированных ≈ проживающих.

# %%
houses_with_ppl = (
    houses_geocoded
    .merge(
        repair_data[["mun_obr", "total_ppl", "house_id"]], 
        how="left",
        on="house_id"
    )
    .dropna(subset="total_ppl")
)
len(houses_with_ppl)
# Out:
# 23505

# %% [markdown]
# В целом это был самый проблемный шаг, так как мы теряем сразу 6 тысяч домов из-за того, что не знаем число проживающих. Теперь объединяем с числом квартир.

# %%
houses_with_n_flats = (
    houses_with_ppl
    .merge(flat_sizes, how="left")
    .fillna({"n_rooms": -1})
)
houses_with_n_flats["n_flats"] = houses_with_n_flats["n_flats"].fillna(houses_with_n_flats["living_quarters_count"])
houses_with_n_flats["n_rooms"] = houses_with_n_flats["n_rooms"].astype(int)
houses_with_n_flats["houseguid"].nunique(), len(houses_with_ppl) - sum(houses_with_n_flats["n_rooms"] == -1)
# Out:
# (23505, 22604)

# %% [markdown]
# Тут мы ничего не потеряли, так как если не знаем число квартир с детализацией по количеству комнат, то просто не детализируем — используем общее число квартир. Но при этом таких домов у нас немного: всего около 900.
#
# Дальше присоединяем среднее число жителей на непустую квартиру с учётом муниципалитета и числа комнат в квартирах.

# %%
houses_with_n_flats_and_ppf = (
    houses_with_n_flats
    .merge(
        ppf_by_mo,
        how="left",
        on=["mun_obr", "n_rooms"]
    )
    .dropna(subset="ppf")
)
houses_with_n_flats_and_ppf["houseguid"].nunique()
# Out:
# 23477

# %%
houses_with_n_flats_and_ppf["houseguid"].nunique() / len(houses)
# Out:
# 0.676512117108031

# %% [markdown]
# На этом шаге потеряли совсем немного, но всего — около трети. Это плохо, но что с этим делать, мы не придумали. Посмотрим на данные.

# %%
houses_with_n_flats_and_ppf.head()
# Out:
#    house_id                             houseguid  exploitation_start_year  \
# 0   8065593  723e2dcf-d203-4dc1-89de-9b41f453916a                   1900.0
# 1   8065593  723e2dcf-d203-4dc1-89de-9b41f453916a                   1900.0
# 2   8065593  723e2dcf-d203-4dc1-89de-9b41f453916a                   1900.0
# 3   7847597  8425ff55-ec42-466a-a993-de4e5faaba3b                   1957.0
# 4   7847597  8425ff55-ec42-466a-a993-de4e5faaba3b                   1957.0
#
#    living_quarters_count  area_residential  \
# 0                   32.0            1171.0
# 1                   32.0            1171.0
# 2                   32.0            1171.0
# 3                  249.0           16649.1
# 4                  249.0           16649.1
#
#                                  address        lat        lon  \
# 0  г. Москва, ул. 10-летия Октября, д. 9  55.727066  37.560168
# 1  г. Москва, ул. 10-летия Октября, д. 9  55.727066  37.560168
# 2  г. Москва, ул. 10-летия Октября, д. 9  55.727066  37.560168
# 3         г. Москва, ул. 1812 года, д. 1  55.734999  37.524101
# 4         г. Москва, ул. 1812 года, д. 1  55.734999  37.524101
#
#               mun_obr  total_ppl  n_rooms     n_flats    sheet_name       ppf
# 0     район Хамовники       79.0        1   12.800000     Хамовники  1.858531
# 1     район Хамовники       79.0        2   12.800000     Хамовники  2.464978
# 2     район Хамовники       79.0        3    4.266667     Хамовники  3.277573
# 3  район Дорогомилово      616.0        3  135.725410  Дорогомилово  3.802443
# 4  район Дорогомилово      616.0        4   95.926230  Дорогомилово  4.901138

# %%
houses_with_n_flats_and_ppf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64728 entries, 0 to 65077
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   house_id                 64728 non-null  int64
#  1   houseguid                64728 non-null  object
#  2   exploitation_start_year  64718 non-null  float64
#  3   living_quarters_count    64728 non-null  float64
#  4   area_residential         64728 non-null  float64
#  5   address                  64728 non-null  object
#  6   lat                      64728 non-null  float64
#  7   lon                      64728 non-null  float64
#  8   mun_obr                  64728 non-null  object
#  9   total_ppl                64728 non-null  float64
#  10  n_rooms                  64728 non-null  int64
#  11  n_flats                  64728 non-null  float64
#  12  sheet_name               64728 non-null  object
#  13  ppf                      64728 non-null  float64
# dtypes: float64(8), int64(2), object(4)
# memory usage: 7.4+ MB

# %% [markdown]
# Теперь важный «костыль»: говорят, что данные переписи 2021 года «кривые» и частично нарисованные. Похоже, что это и правда так, потому что если мы посмотрим [московский статистический ежегодник](https://77.rosstat.gov.ru/folder/65047) за 2023 год, то там будет довольно резкий и труднообъяснимый скачок в среднем числе жителей на квартиру: с примерно 3 до 2.7–2.8 (с. 64, дальше делим за каждый год среднюю площадь квартиры на среднюю жилплощадь на человека). Чтобы исправить предположительную «кривизну» данных, вводим поправочный коэффициент, который считаем как среднюю «амплитуду» этого скачка.

# %%
coef = np.mean([56.9 / 19.3, 56.9 / 19.4, 57.2 / 19.6]) / np.mean([59.5 / 21.7, 59.7 / 21.8])
coef
# Out:
# np.float64(1.0704127479744514)

# %% [markdown]
# А теперь сам подсчёт:
# - вставляем «костыль»;
# - считаем ожидаемое число жителей в доме;
# - считаем среднее число жителей на непустую квартиру для каждого дома;
# - из разности ожидаемого и реального числа жителей и среднего числа жителей на пустую квартиру считаем число вакантных квартир;
# - также вычисляем долю вакантных квартир;
# - сводим всё в таблицу, где одна строка соответствует одному дому (было не так, потому что в ходе подсчётов присоединялись данные по числу комнат в квартирах, а они шли в long-формате, где одному дому соответствовало несколько строк).

# %%
vacant = houses_with_n_flats_and_ppf.copy()
vacant["ppf"] = vacant["ppf"] * coef  # dirty hack to workaround shitty 202(1) census
vacant["ppl"] = vacant["n_flats"] * vacant["ppf"]
vacant["expected_total_ppl"] = vacant.groupby("houseguid")["ppl"].transform("sum")
vacant["house_ppf"] = vacant["expected_total_ppl"] / vacant["living_quarters_count"]
vacant["theoretical_non_vacant_flats"] = vacant["total_ppl"] / vacant["house_ppf"]
vacant["vacant_flats_count"] = np.round(vacant["living_quarters_count"] - vacant["theoretical_non_vacant_flats"])
vacant["vacant_flats_share"] = vacant["vacant_flats_count"] / vacant["living_quarters_count"]
vacant.drop_duplicates("houseguid", inplace=True)
vacant.drop(columns=["area_residential", "n_rooms", "n_flats", "sheet_name", "ppf", "ppl", "expected_total_ppl"], inplace=True)
vacant.head()
# Out:
#     house_id                             houseguid  exploitation_start_year  \
# 0    8065593  723e2dcf-d203-4dc1-89de-9b41f453916a                   1900.0
# 3    7847597  8425ff55-ec42-466a-a993-de4e5faaba3b                   1957.0
# 5    7847598  a8ad9e0b-e0c1-46a7-981c-4d5a598c76ce                   1954.0
# 7    7847599  91c77deb-3ff8-4413-a827-29cc00aa5720                   1957.0
# 11   7847601  e6a48610-b5d7-4ed3-9ef8-a5dd64496404                   1971.0
#
#     living_quarters_count                                  address        lat  \
# 0                    32.0    г. Москва, ул. 10-летия Октября, д. 9  55.727066
# 3                   249.0           г. Москва, ул. 1812 года, д. 1  55.734999
# 5                   325.0           г. Москва, ул. 1812 года, д. 2  55.736789
# 7                   119.0           г. Москва, ул. 1812 года, д. 3  55.736122
# 11                  108.0  г. Москва, ул. 1812 года, д. 4/45, к. 2  55.736559
#
#           lon             mun_obr  total_ppl  house_ppf  \
# 0   37.560168     район Хамовники       79.0   2.318956
# 3   37.524101  район Дорогомилово      616.0   4.239676
# 5   37.524575  район Дорогомилово      829.0   4.386986
# 7   37.523309  район Дорогомилово      290.0   3.156856
# 11  37.526142  район Дорогомилово      212.0   3.297799
#
#     theoretical_non_vacant_flats  vacant_flats_count  vacant_flats_share
# 0                      34.067053                -2.0           -0.062500
# 3                     145.294112               104.0            0.417671
# 5                     188.968016               136.0            0.418462
# 7                      91.863536                27.0            0.226891
# 11                     64.285310                44.0            0.407407

# %%
vacant.loc[vacant["vacant_flats_share"] > 0, "vacant_flats_share"].describe()
# Out:
# count    20302.000000
# mean         0.354648
# std          0.245342
# min          0.003205
# 25%          0.187500
# 50%          0.302083
# 75%          0.440843
# max          1.000000
# Name: vacant_flats_share, dtype: float64

# %% [markdown]
# Простейший способ проверить результат — посмотреть, много ли получилось отрицательных значений, которые невозможны.

# %%
(vacant["vacant_flats_count"] >= 0).value_counts() / len(vacant)
# Out:
# vacant_flats_count
# True     0.875879
# False    0.124121
# Name: count, dtype: float64

# %%
vacant_correct = vacant.loc[vacant["vacant_flats_count"] >= 0]
len(vacant_correct)
# Out:
# 20563

# %%
20653/34703
# Out:
# 0.5951358672160908

# %% [markdown]
# К сожалению, заведомо неправильные результаты есть, но к счастью, для 20.5 тысяч домов получилась адекватная оценка. Это даже больше половины от исходного количества :) Можно было лучше, но для первичной оценки достаточно.
#
# Сразу посчитаем статистику в разрезе муниципальных образований.

# %%
vacant_by_mo = vacant_correct.groupby("mun_obr")[["vacant_flats_share"]].median()
vacant_by_mo.head()
# Out:
#                      vacant_flats_share
# mun_obr
# Академический район            0.314801
# Алексеевский район             0.381653
# Алтуфьевский район             0.218182
# Бабушкинский район             0.202589
# Басманный район                0.290570

# %% [markdown]
# Порисуем диаграммы распределения.

# %%
vacant_correct["vacant_flats_count"].hist(bins=100)
# Out:
# <Axes: >

# %%
vacant_correct["vacant_flats_share"].hist(bins=100)
# Out:
# <Axes: >

# %% [markdown]
# Сохраним результат.

# %%
pathlib.Path("../result").mkdir(parents=True, exist_ok=True)
vacant_correct.to_csv("../result/vacant_w1.csv", index=False)

# %%
vacant_by_mo.to_csv("../result/vacant_by_mo.csv", index=False)

# %% [markdown]
# # Итоги
#
# ## Плюсы
#
# 1. Оно работает.
# 2. Оно опирается исключительно на общедоступные данные.
# 3. Оно считается на уровне домов: с одной стороны, достаточно детально, а с другой стороны, не «сливает» персональные данные жителей (и вообще их не использует).
# 4. Оно масштабируется на всю страну, если повозиться со сбором сведений.
# 5. Оно масштабируется на другой временной период, если взять данные за прошлое время.
#
# ## Минусы
#
# 1. Методика заведомо неточная и порождает очевидные ошибки.
# 2. Большое количество домов исключается из расчётов из-за нехватки данных или других проблем.
#
# ## Возможности улучшения
#
# 1. Более точные и полные данные.
# 2. Ground-truth валидация результатов.
